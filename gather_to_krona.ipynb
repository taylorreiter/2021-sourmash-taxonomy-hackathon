# %% [markdown]
# # Converting the `sourmash gather` output to format required for `krona` visualization

# %% [markdown]
# lineage files need to be downloaded before they're used.
# Below we provide documentation for their locations.
#
# ### Paths to lineage files on farm
#
# **Genbank**
# ```
# /home/irber/sourmash_databases/outputs/lca/lineages/protozoa_genbank_lineage.csv
# /home/irber/sourmash_databases/outputs/lca/lineages/fungi_genbank_lineage.csv
# /home/irber/sourmash_databases/outputs/lca/lineages/viral_genbank_lineage.csv
# /home/irber/sourmash_databases/outputs/lca/lineages/bacteria_genbank_lineage.csv
# /home/irber/sourmash_databases/outputs/lca/lineages/archaea_genbank_lineage.csv
# ```
#
# **GTDB**
# ```
# /group/ctbrowngrp/gtdb/gtdb-rs202.taxonomy.csv
# ```
#
# ### download links for lineage files
#
# **Genbank**
# ```
# wget -O viral_genbank_lineage.csv https://osf.io/q2emr/download
# wget -O protozoa_genbank_lineage.csv https://osf.io/urtfx/download
# wget -O fungi_genbank_lineage.csv https://osf.io/9u6qh/download
# wget -O archaea_genbank_lineage.csv https://osf.io/mv5hs/download
# wget -O bacteria_genbank_lineage.csv https://osf.io/cbhgd/download
# ```
#
#
# **GTDB**
# ```
# wget -O gtdb-rs202.taxonomy.v2.csv https://osf.io/p6z3w/download
# ```

# %% [markdown]
# ## Summarize gather to lineage

# %%
# !wget -O viral_genbank_lineage.csv https://osf.io/q2emr/download
# !wget -O protozoa_genbank_lineage.csv https://osf.io/urtfx/download
# !wget -O fungi_genbank_lineage.csv https://osf.io/9u6qh/download
# !wget -O archaea_genbank_lineage.csv https://osf.io/mv5hs/download
# !wget -O bacteria_genbank_lineage.csv https://osf.io/cbhgd/download
# Out:
# --2021-05-24 16:21:33--  https://osf.io/q2emr/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac309aa480c602300d3c01?action=download&direct&version=1 [following]
# --2021-05-24 16:21:33--  https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac309aa480c602300d3c01?action=download&direct&version=1
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4476110 (4.3M) [text/csv]
# Saving to: ‘viral_genbank_lineage.csv’
#
# viral_genbank_linea 100%[===================>]   4.27M  17.9MB/s    in 0.2s
#
# 2021-05-24 16:21:34 (17.9 MB/s) - ‘viral_genbank_lineage.csv’ saved [4476110/4476110]
#
# --2021-05-24 16:21:34--  https://osf.io/urtfx/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac30bb8a5d3d02480cbedc?action=download&direct&version=1 [following]
# --2021-05-24 16:21:35--  https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac30bb8a5d3d02480cbedc?action=download&direct&version=1
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110005 (107K) [text/csv]
# Saving to: ‘protozoa_genbank_lineage.csv’
#
# protozoa_genbank_li 100%[===================>] 107.43K  --.-KB/s    in 0.08s
#
# 2021-05-24 16:21:36 (1.37 MB/s) - ‘protozoa_genbank_lineage.csv’ saved [110005/110005]
#
# --2021-05-24 16:21:36--  https://osf.io/9u6qh/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac30ba0b6c6902519bcb5e?action=download&direct&version=1 [following]
# --2021-05-24 16:21:36--  https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac30ba0b6c6902519bcb5e?action=download&direct&version=1
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 849177 (829K) [text/csv]
# Saving to: ‘fungi_genbank_lineage.csv’
#
# fungi_genbank_linea 100%[===================>] 829.27K  --.-KB/s    in 0.1s
#
# 2021-05-24 16:21:37 (6.37 MB/s) - ‘fungi_genbank_lineage.csv’ saved [849177/849177]
#
# --2021-05-24 16:21:37--  https://osf.io/mv5hs/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac30baa480c602300d3c3e?action=download&direct&version=1 [following]
# --2021-05-24 16:21:38--  https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac30baa480c602300d3c3e?action=download&direct&version=1
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 604898 (591K) [text/csv]
# Saving to: ‘archaea_genbank_lineage.csv’
#
# archaea_genbank_lin 100%[===================>] 590.72K  --.-KB/s    in 0.1s
#
# 2021-05-24 16:21:40 (5.10 MB/s) - ‘archaea_genbank_lineage.csv’ saved [604898/604898]
#
# --2021-05-24 16:21:40--  https://osf.io/cbhgd/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac3146a480c602300d3d23?action=download&direct&version=1 [following]
# --2021-05-24 16:21:40--  https://files.osf.io/v1/resources/t3fqa/providers/osfstorage/60ac3146a480c602300d3d23?action=download&direct&version=1
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87205728 (83M) [text/csv]
# Saving to: ‘bacteria_genbank_lineage.csv’
#
# bacteria_genbank_li 100%[===================>]  83.17M  40.9MB/s    in 2.0s
#
# 2021-05-24 16:21:44 (40.9 MB/s) - ‘bacteria_genbank_lineage.csv’ saved [87205728/87205728]

# %%
# !cat *genbank_lineage.csv > all_genbank_lineages.csv

# %%
# !scripts/gather-to-tax.py outputs/gather/HSMA33MX_gather_x_genbank_k31.csv all_genbank_lineages.csv > outputs/gather/HSMA33MX_gather_x_genbank_k31_lineage.txt
# Out:
# examining spreadsheet headers...
# ** assuming column 'accession' is identifiers in spreadsheet

# %% [markdown]
# ## Read in summarized lineages and format for krona

# %%
import pandas as pd

# %%
# R code to read in lineages using tidyverse
# read_delim("outputs/gather/HSMA33MX_gather_x_genbank_k31_lineage.txt", delim = ";", skip=3, col_names = c("tmp", "phylum", "class", "order", "family", "genus", "species") %>%
#  separate(col = tmp, into = c("level", "fraction", "superkingdom"), sep = " ") %>%
#  mutate(lineage = paste(superkingdom, phylum, class, order, family, genus, species, sep = ";"))

# %%
# read in the lineage information, dealing with the funny formatting
lineage = pd.read_csv("outputs/gather/HSMA33MX_gather_x_genbank_k31_lineage.txt",
                      sep = ";", skiprows = 4, header = None,
                      names = ["tmp", "phylum", "class", "order", "family", "genus", "species"])

# %%
lineage.head()
# Out:
#                             tmp          phylum class order family genus  \
# 0  superkingdom 0.245 Eukaryota             NaN   NaN   NaN    NaN   NaN
# 1   superkingdom 0.131 Bacteria             NaN   NaN   NaN    NaN   NaN
# 2        phylum 0.245 Eukaryota     Apicomplexa   NaN   NaN    NaN   NaN
# 3         phylum 0.073 Bacteria   Bacteroidetes   NaN   NaN    NaN   NaN
# 4         phylum 0.058 Bacteria  Proteobacteria   NaN   NaN    NaN   NaN
#
#   species
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# finish dealing with the funny formatting
lineage[['level', 'fraction', 'superkingdom']] = lineage.tmp.apply(
   lambda x: pd.Series(str(x).split(" ")))
cols = ['level', 'fraction', 'superkingdom', "phylum", "class", "order", "family", "genus", "species"]
lineage = lineage[cols]
lineage.head()
# Out:
#           level fraction superkingdom          phylum class order family  \
# 0  superkingdom    0.245    Eukaryota             NaN   NaN   NaN    NaN
# 1  superkingdom    0.131     Bacteria             NaN   NaN   NaN    NaN
# 2        phylum    0.245    Eukaryota     Apicomplexa   NaN   NaN    NaN
# 3        phylum    0.073     Bacteria   Bacteroidetes   NaN   NaN    NaN
# 4        phylum    0.058     Bacteria  Proteobacteria   NaN   NaN    NaN
#
#   genus species
# 0   NaN     NaN
# 1   NaN     NaN
# 2   NaN     NaN
# 3   NaN     NaN
# 4   NaN     NaN

# %%
# filter to species
# note that if something isn't classified down to the species, I think it will get dropped here...
species = lineage[lineage['level'] == "species"]
species.head()
# Out:
#       level fraction superkingdom          phylum                class  \
# 23  species    0.222    Eukaryota     Apicomplexa         Aconoidasida
# 24  species    0.058     Bacteria  Proteobacteria  Gammaproteobacteria
# 25  species    0.057     Bacteria   Bacteroidetes          Bacteroidia
# 26  species    0.023    Eukaryota     Apicomplexa          Conoidasida
# 27  species    0.016     Bacteria   Bacteroidetes          Bacteroidia
#
#                order              family        genus               species
# 23      Haemosporida        Plasmodiidae   Plasmodium      Plasmodium vivax
# 24  Enterobacterales  Enterobacteriaceae  Escherichia      Escherichia coli
# 25     Bacteroidales      Prevotellaceae   Prevotella      Prevotella copri
# 26    Eucoccidiorida       Sarcocystidae   Toxoplasma     Toxoplasma gondii
# 27     Bacteroidales      Bacteroidaceae  Bacteroides  Bacteroides vulgatus

# %%
# format for krona
# Use ktImportText to create a chart based on a text file that lists values and wedge hierarchies to add them to. 
# Each line should be an optional quantity followed by list of wedges to contribute to (starting from the highest level), separated by tabs.
# If a hierarchy has more than one listing, the quantities will be added.
cols = ['fraction', 'superkingdom', "phylum", "class", "order", "family", "genus", "species"]
species = species[cols]
species.to_csv("outputs/gather/HSMA33MX_gather_x_genbank_k31_krona.txt", sep = "\t", index = False)

# %%
# !ktImportText outputs/gather/HSMA33MX_gather_x_genbank_k31_krona.txt
# Out:
# Writing text.krona.html...

# %% [markdown]
# ![](_static/krona_screenshot.png)
